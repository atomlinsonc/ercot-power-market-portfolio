# %% [markdown]
# # Sample Data Exploration
#
# Starter notebook for reviewing mock ERCOT-style data before live public-data integration.

# %%
import pandas as pd

data = pd.read_csv('../data/processed/sample_ercot_market_data.csv', parse_dates=['timestamp'])
data.head()
