# %% [markdown]
# # Price Spike Detection
#
# Starter notebook for exploring threshold-based price spike detection.

# %%
import pandas as pd

data = pd.read_csv('../data/processed/sample_ercot_market_data.csv', parse_dates=['timestamp'])
data[data['real_time_price'] >= 150].sort_values('real_time_price', ascending=False).head()
