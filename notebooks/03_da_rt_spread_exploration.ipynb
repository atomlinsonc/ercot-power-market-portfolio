# %% [markdown]
# # DA/RT Spread Exploration
#
# Starter notebook for analyzing day-ahead minus real-time spreads.

# %%
import pandas as pd

data = pd.read_csv('../data/processed/sample_ercot_market_data.csv', parse_dates=['timestamp'])
data.groupby('settlement_point')['da_rt_spread'].agg(['mean', 'min', 'max']).sort_values('mean')
